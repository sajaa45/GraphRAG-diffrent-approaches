# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from IPython.display import display, HTML
# Set the format for floating point numbers to show no decimal places
pd.set_option('display.float_format', lambda x: '%.0f' % x)
# To display plots inline within the notebook
# %matplotlib inline
# Set the notebook width to 100%

# %%
numericFacts   = pd.read_csv('/kaggle/input/datasets/sajamoussa/2026m2/num.tsv', sep='\t', low_memory=False, keep_default_na=False)
submissions  = pd.read_csv('/kaggle/input/datasets/sajamoussa/2026m2/sub.tsv', sep='\t', low_memory=False, keep_default_na=False)
tags  = pd.read_csv('/kaggle/input/datasets/sajamoussa/2026m2/tag.tsv', sep='\t', low_memory=False, keep_default_na=False)
print('Sum of Filings:', str(len(numericFacts) + len(submissions) + len(tags)))
# Out:
# Sum of Filings: 5500389

# %%
submissions
# Out:
#                       adsh      cik                                 name  \
# 0     0000002488-26-000014     2488           ADVANCED MICRO DEVICES INC
# 1     0000002488-26-000018     2488           ADVANCED MICRO DEVICES INC
# 2     0000002488-26-000021     2488           ADVANCED MICRO DEVICES INC
# 3     0000003545-26-000010     3545                          ALICO, INC.
# 4     0000003545-26-000012     3545                          ALICO, INC.
# ...                    ...      ...                                  ...
# 8751  0002074176-26-000005  2074176                   VIPER ENERGY, INC.
# 8752  0002074176-26-000010  2074176                   VIPER ENERGY, INC.
# 8753  0002082557-26-000013  2082557  GOLUB CAPITAL PRIVATE INCOME FUND S
# 8754  0002082559-26-000018  2082559  GOLUB CAPITAL PRIVATE INCOME FUND I
# 8755  0002089661-26-000016  2089661                       SUNOCOCORP LLC
#
#        sic countryba stprba       cityba  zipba  \
# ...

# %%
submissions.columns
# Out:
# Index(['adsh', 'cik', 'name', 'sic', 'countryba', 'stprba', 'cityba', 'zipba',
#        'bas1', 'bas2', 'baph', 'countryma', 'stprma', 'cityma', 'zipma',
#        'mas1', 'mas2', 'countryinc', 'stprinc', 'ein', 'former', 'changed',
#        'afs', 'wksi', 'fye', 'form', 'period', 'fy', 'fp', 'filed', 'accepted',
#        'prevrpt', 'detail', 'instance', 'nciks', 'aciks', 'pubfloatusd',
#        'floatdate', 'floataxis', 'floatmems'],
#       dtype='object')

# %%
submissions.drop(columns=['countryba', 'stprba', 'cityba', 'zipba',
       'bas1', 'bas2', 'baph', 'countryma', 'stprma', 'cityma', 'zipma',
       'mas1', 'mas2', 'countryinc', 'stprinc', 'ein', 'former', 'changed',
       'afs', 'wksi', 'fye', 'period', 'fy', 'fp', 'filed', 'accepted',
       'prevrpt', 'detail', 'instance', 'nciks', 'aciks', 'pubfloatusd',
       'floatdate', 'floataxis', 'floatmems'], inplace=True)

# %%
submissions.columns
# Out:
# Index(['adsh', 'cik', 'name', 'sic', 'form'], dtype='object')

# %%
submissions.head()
# Out:
#                    adsh   cik                        name   sic    form
# 0  0000002488-26-000014  2488  ADVANCED MICRO DEVICES INC  3674     8-K
# 1  0000002488-26-000018  2488  ADVANCED MICRO DEVICES INC  3674    10-K
# 2  0000002488-26-000021  2488  ADVANCED MICRO DEVICES INC  3674  10-K/A
# 3  0000003545-26-000010  3545                 ALICO, INC.  0100     8-K
# 4  0000003545-26-000012  3545                 ALICO, INC.  0100    10-Q

# %%
Annualsubmissions = submissions[
    submissions['form'] == '10-K'
]

# %%
submissions.head()
# Out:
#                    adsh   cik                        name   sic    form
# 0  0000002488-26-000014  2488  ADVANCED MICRO DEVICES INC  3674     8-K
# 1  0000002488-26-000018  2488  ADVANCED MICRO DEVICES INC  3674    10-K
# 2  0000002488-26-000021  2488  ADVANCED MICRO DEVICES INC  3674  10-K/A
# 3  0000003545-26-000010  3545                 ALICO, INC.  0100     8-K
# 4  0000003545-26-000012  3545                 ALICO, INC.  0100    10-Q

# %%
numericFacts
# Out:
#                          adsh  \
# 0        0000002488-26-000018
# 1        0000002488-26-000018
# 2        0000002488-26-000018
# 3        0000002488-26-000018
# 4        0000002488-26-000018
# ...                       ...
# 4990814  0002089661-26-000016
# 4990815  0002089661-26-000016
# 4990816  0002089661-26-000016
# 4990817  0002089661-26-000016
# 4990818  0002089661-26-000016
#
#                                                      tag       version  \
# 0                                 AccountsPayableCurrent  us-gaap/2025
# 1                                 AccountsPayableCurrent  us-gaap/2025
# 2                    AccountsPayableCurrentAndNoncurrent  us-gaap/2025
# 3                    AccountsPayableCurrentAndNoncurrent  us-gaap/2025
# 4                           AccountsReceivableNetCurrent  us-gaap/2025
# ...                                                  ...           ...
# 4990814                                VariableLeaseCost  us-gaap/2025
# ...

# %%
numericFacts
# Out:
#                          adsh  \
# 0        0000002488-26-000018
# 1        0000002488-26-000018
# 2        0000002488-26-000018
# 3        0000002488-26-000018
# 4        0000002488-26-000018
# ...                       ...
# 4990814  0002089661-26-000016
# 4990815  0002089661-26-000016
# 4990816  0002089661-26-000016
# 4990817  0002089661-26-000016
# 4990818  0002089661-26-000016
#
#                                                      tag       version  \
# 0                                 AccountsPayableCurrent  us-gaap/2025
# 1                                 AccountsPayableCurrent  us-gaap/2025
# 2                    AccountsPayableCurrentAndNoncurrent  us-gaap/2025
# 3                    AccountsPayableCurrentAndNoncurrent  us-gaap/2025
# 4                           AccountsReceivableNetCurrent  us-gaap/2025
# ...                                                  ...           ...
# 4990814                                VariableLeaseCost  us-gaap/2025
# ...

# %%
numericFacts.columns
# Out:
# Index(['adsh', 'tag', 'version', 'ddate', 'qtrs', 'uom', 'dimh', 'iprx',
#        'value', 'footnote', 'footlen', 'dimn', 'coreg', 'durp', 'datp',
#        'dcml'],
#       dtype='object')

# %%
numericFacts.drop(columns=['version', 'uom', 'dimh', 'iprx', 'footlen', 'dimn', 'coreg', 'durp', 'datp',
       'dcml'], inplace=True)

# %%
numericFacts.head()
# Out:
#                    adsh                                  tag     ddate  qtrs  \
# 0  0000002488-26-000018               AccountsPayableCurrent  20241231     0
# 1  0000002488-26-000018               AccountsPayableCurrent  20251231     0
# 2  0000002488-26-000018  AccountsPayableCurrentAndNoncurrent  20241231     0
# 3  0000002488-26-000018  AccountsPayableCurrentAndNoncurrent  20251231     0
# 4  0000002488-26-000018         AccountsReceivableNetCurrent  20241231     0
#
#              value footnote
# 0  2466000000.0000
# 1  2929000000.0000
# 2   476000000.0000
# 3   408000000.0000
# 4  6192000000.0000

# %%
tags
# Out:
#                                             tag               version  custom  \
# 0       A.5000EuroDenominatedNotesDue2033Member  0000059478-26-000013       1
# 1                       A.B.BrownFacilityMember  0001130310-26-000008       1
# 2            A.C.SolucoesParaPiscinasLda.Member  0001193125-26-074833       1
# 3                                      A.Member  0000909327-26-000022       1
# 4                               A.PacificMember  0001628280-26-010047       1
# ...                                         ...                   ...     ...
# 500809                                 ZZ524292            naics/2025       0
# 500810                                 ZZ525110            naics/2025       0
# 500811                                 ZZ541214            naics/2025       0
# 500812                                 ZZ541990            naics/2025       0
# 500813                                 ZZ811412            naics/2025       0
#
# ...

# %%
Texts   = pd.read_csv('/kaggle/input/datasets/sajamoussa/2026m2/txt.tsv', sep='\t', low_memory=False, keep_default_na=False)

# %%
Texts
# Out:
#                         adsh                                    tag  \
# 0       0000002488-26-000014                          AmendmentFlag
# 1       0000002488-26-000014                           CityAreaCode
# 2       0000002488-26-000014                  DocumentPeriodEndDate
# 3       0000002488-26-000014                           DocumentType
# 4       0000002488-26-000014              EntityAddressAddressLine1
# ...                      ...                                    ...
# 687998  0002089661-26-000016  TradeAndOtherAccountsReceivablePolicy
# 687999  0002089661-26-000016                          TradingSymbol
# 688000  0002089661-26-000016  UnitsOfPartnershipInterestDescription
# 688001  0002089661-26-000016  UnitsOfPartnershipInterestDescription
# 688002  0002089661-26-000016                         UseOfEstimates
#
#              version     ddate  qtrs  iprx   lang   dcml  durp  datp  \
# 0           dei/2025  20260131     0     0  en-US  32767     0    -3
# ...

# %%
Texts.columns
# Out:
# Index(['adsh', 'tag', 'version', 'ddate', 'qtrs', 'iprx', 'lang', 'dcml',
#        'durp', 'datp', 'dimh', 'dimn', 'coreg', 'escaped', 'srclen', 'txtlen',
#        'footnote', 'footlen', 'context', 'value'],
#       dtype='object')

# %%
Texts.drop(columns=[ 'iprx', 'lang', 'dcml',
       'durp', 'datp', 'dimh', 'dimn', 'coreg', 'escaped', 'srclen', 'txtlen',
        'footlen', 'context'], inplace=True)

# %%
Texts.head()
# Out:
#                    adsh                        tag   version     ddate  qtrs  \
# 0  0000002488-26-000014              AmendmentFlag  dei/2025  20260131     0
# 1  0000002488-26-000014               CityAreaCode  dei/2025  20260131     0
# 2  0000002488-26-000014      DocumentPeriodEndDate  dei/2025  20260131     0
# 3  0000002488-26-000014               DocumentType  dei/2025  20260131     0
# 4  0000002488-26-000014  EntityAddressAddressLine1  dei/2025  20260131     0
#
#   footnote                 value
# 0                          false
# 1                            408
# 2                     2026-02-03
# 3                            8-K
# 4           2485 Augustine Drive

# %%
joinedFactsAndSubmissions = numericFacts.join(submissions.set_index('adsh'), on = 'adsh')

# %%
joinedFactsAndSubmissions
# Out:
#                          adsh  \
# 0        0000002488-26-000018
# 1        0000002488-26-000018
# 2        0000002488-26-000018
# 3        0000002488-26-000018
# 4        0000002488-26-000018
# ...                       ...
# 4990814  0002089661-26-000016
# 4990815  0002089661-26-000016
# 4990816  0002089661-26-000016
# 4990817  0002089661-26-000016
# 4990818  0002089661-26-000016
#
#                                                      tag     ddate  qtrs  \
# 0                                 AccountsPayableCurrent  20241231     0
# 1                                 AccountsPayableCurrent  20251231     0
# 2                    AccountsPayableCurrentAndNoncurrent  20241231     0
# 3                    AccountsPayableCurrentAndNoncurrent  20251231     0
# 4                           AccountsReceivableNetCurrent  20241231     0
# ...                                                  ...       ...   ...
# 4990814                                VariableLeaseCost  20251231     4
# ...

# %%
annual_forms = ['10-K', '20-F', '40-F']  

joinedFactsAndSubmissionsAnnual = joinedFactsAndSubmissions[
    (joinedFactsAndSubmissions['form'].isin(annual_forms))
]
joinedFactsAndSubmissionsAnnual
# Out:
#                          adsh  \
# 0        0000002488-26-000018
# 1        0000002488-26-000018
# 2        0000002488-26-000018
# 3        0000002488-26-000018
# 4        0000002488-26-000018
# ...                       ...
# 4990814  0002089661-26-000016
# 4990815  0002089661-26-000016
# 4990816  0002089661-26-000016
# 4990817  0002089661-26-000016
# 4990818  0002089661-26-000016
#
#                                                      tag     ddate  qtrs  \
# 0                                 AccountsPayableCurrent  20241231     0
# 1                                 AccountsPayableCurrent  20251231     0
# 2                    AccountsPayableCurrentAndNoncurrent  20241231     0
# 3                    AccountsPayableCurrentAndNoncurrent  20251231     0
# 4                           AccountsReceivableNetCurrent  20241231     0
# ...                                                  ...       ...   ...
# 4990814                                VariableLeaseCost  20251231     4
# ...

# %%
joinedTextAndSubmissions = Texts.join(submissions.set_index('adsh'), on = 'adsh')

# %%
joinedTextAndSubmissions
# Out:
#                         adsh                                    tag  \
# 0       0000002488-26-000014                          AmendmentFlag
# 1       0000002488-26-000014                           CityAreaCode
# 2       0000002488-26-000014                  DocumentPeriodEndDate
# 3       0000002488-26-000014                           DocumentType
# 4       0000002488-26-000014              EntityAddressAddressLine1
# ...                      ...                                    ...
# 687998  0002089661-26-000016  TradeAndOtherAccountsReceivablePolicy
# 687999  0002089661-26-000016                          TradingSymbol
# 688000  0002089661-26-000016  UnitsOfPartnershipInterestDescription
# 688001  0002089661-26-000016  UnitsOfPartnershipInterestDescription
# 688002  0002089661-26-000016                         UseOfEstimates
#
#              version     ddate  qtrs footnote  \
# 0           dei/2025  20260131     0
# 1           dei/2025  20260131     0
# ...

# %%
annual_forms = ['10-K', '20-F', '40-F']  

joinedTextAndSubmissionsAnnual = joinedTextAndSubmissions[
    (joinedTextAndSubmissions['form'].isin(annual_forms))
]
joinedTextAndSubmissionsAnnual
# Out:
#                         adsh                                    tag  \
# 22      0000002488-26-000018        AdvertisingCostsPolicyTextBlock
# 23      0000002488-26-000018                          AmendmentFlag
# 24      0000002488-26-000018                          AuditorFirmId
# 25      0000002488-26-000018                        AuditorLocation
# 26      0000002488-26-000018                            AuditorName
# ...                      ...                                    ...
# 687998  0002089661-26-000016  TradeAndOtherAccountsReceivablePolicy
# 687999  0002089661-26-000016                          TradingSymbol
# 688000  0002089661-26-000016  UnitsOfPartnershipInterestDescription
# 688001  0002089661-26-000016  UnitsOfPartnershipInterestDescription
# 688002  0002089661-26-000016                         UseOfEstimates
#
#              version     ddate  qtrs footnote  \
# 22      us-gaap/2025  20251231     4
# 23          dei/2025  20251231     4
# ...

# %%
unique_sic = submissions['sic'].unique()
print(f"Count: {len(unique_sic)}")
# Out:
# Count: 366

# %%
joinedTextAndSubmissions1311 = joinedTextAndSubmissionsAnnual[
    (joinedTextAndSubmissionsAnnual['sic'] == '1311')
]
joinedFactsAndSubmissions1311 = joinedFactsAndSubmissionsAnnual[
    (joinedFactsAndSubmissionsAnnual['sic'] == '1311') ]

# %%
joinedTextAndSubmissions1311
# Out:
#                         adsh  \
# 12672   0000033213-26-000018
# 12673   0000033213-26-000018
# 12674   0000033213-26-000018
# 12675   0000033213-26-000018
# 12676   0000033213-26-000018
# ...                      ...
# 687459  0002074176-26-000010
# 687460  0002074176-26-000010
# 687461  0002074176-26-000010
# 687462  0002074176-26-000010
# 687463  0002074176-26-000010
#
#                                                       tag  \
# 12672                                       AmendmentFlag
# 12673   AssetRetirementObligationsAndEnvironmentalCost...
# 12674            AssetsAndLiabilitiesLesseeTableTextBlock
# 12675                                       AuditorFirmId
# 12676                                     AuditorLocation
# ...                                                   ...
# 687459                          SubsequentEventsTextBlock
# 687460     TaxJurisdictionOfDomicileExtensibleEnumeration
# 687461              TradeAndOtherAccountsReceivablePolicy
# ...

# %%
joinedFactsAndSubmissions1311
# Out:
#                          adsh                                            tag  \
# 128912   0000033213-26-000018                         AccountsPayableCurrent
# 128913   0000033213-26-000018                         AccountsPayableCurrent
# 128914   0000033213-26-000018                   AccountsReceivableNetCurrent
# 128915   0000033213-26-000018                   AccountsReceivableNetCurrent
# 128916   0000033213-26-000018       AccrualForEnvironmentalLossContingencies
# ...                       ...                                            ...
# 4986389  0002074176-26-000010  WeightedAverageNumberOfSharesOutstandingBasic
# 4986390  0002074176-26-000010  WeightedAverageNumberOfSharesOutstandingBasic
# 4986391  0002074176-26-000010  WeightedAverageNumberOfSharesOutstandingBasic
# 4986392  0002074176-26-000010  WeightedAverageNumberOfSharesOutstandingBasic
# 4986393  0002074176-26-000010  WeightedAverageNumberOfSharesOutstandingBasic
#
# ...

# %%
debt_ebitda_data = joinedFactsAndSubmissionsAnnual[
    joinedFactsAndSubmissionsAnnual['tag'].str.contains('Debt', case=False, na=False) &
    joinedFactsAndSubmissionsAnnual['tag'].str.contains('EBITDA', case=False, na=False)
]
debt_ebitda_data['tag'].unique()
# Out:
# array(['DebtInstrumentCovenantComplianceRatioOfConsolidatedNetDebtToConsolidatedEBITDA',
#        'DebtInstrumentCovenantEBITDARatioMaximum',
#        'DebtInstrumentCovenantEBITDARatioQuarterlyDecrease',
#        'DebtInstrumentCovenantNetDebtToConsolidatedAdjustedEBITDARatio',
#        'NetDebtToConsolidatedAdjustedEBITDARatio',
#        'DebtInstrumentCovenantNetDebtToEBITDARatioMaximum',
#        'RatioOfIndebtednessToEBITDA', 'DebtInstrumentEBITDARatioCovenant',
#        'DebtInstrumentCovenantMaximumDebtToEBITDARatio',
#        'DebtInstrumentCovenantEBITDAToInterestExpenseRatioMaximum',
#        'DebtInstrumentCovenantMinimumPermittedAcquisitionAlternativeRequirementsForIndebtednessToEBITDARatio',
#        'DebtInstrumentCovenantSeniorSecuredNetIndebtednessToAdjustedEBITDARatioMaximum',
#        'DebtInstrumentNumberOfInstancesRatioOfDebtToEBITDAExceeded',
#        'DebtInstrumentRatioOfDebtToEBITDA',
#        'DebtInstrumentRatioOfDebtToEBITDAAfterAcquisition',
# ...

# %%
count = len(debt_ebitda_data[debt_ebitda_data['tag'] == 'DebtInstrumentCovenantComplianceRatioOfConsolidatedNetDebtToConsolidatedEBITDA'])
print(f"NetDebtToEBITDARatio appears {count} times")
# Out:
# NetDebtToEBITDARatio appears 2 times

# %%
# Define the tags you want to check
debt_ebitda_tags = [
    'DebtInstrumentCovenantComplianceRatioOfConsolidatedNetDebtToConsolidatedEBITDA',
    'NetDebtToEBITDARatio',
    'DebtToEbitda',
    'ActualDebtToEbitdaRatio',
    'DebtInstrumentCovenantDebtToEBITDARatio',
    'DebtInstrumentCovenantMaximumDebtToEBITDARatio',
    'DebtInstrumentCovenantNetDebtToEBITDARatio',
    'RatioOfIndebtednessToEBITDA',
    'DebtInstrumentCovenantConsolidatedIndebtednessToConsolidatedEBITDAMaximum',
    'DebtToEbitdaRatioMaximum'
]

# Count occurrences for each tag
for tag in debt_ebitda_tags:
    count = (joinedFactsAndSubmissionsAnnual['tag'] == tag).sum()
    if count > 0:
        print(f"{tag}: {count} times")
    else:
        print(f"{tag}: NOT FOUND")
# Out:
# DebtInstrumentCovenantComplianceRatioOfConsolidatedNetDebtToConsolidatedEBITDA: 2 times
# NetDebtToEBITDARatio: 1 times
# DebtToEbitda: 2 times
# ActualDebtToEbitdaRatio: 1 times
# DebtInstrumentCovenantDebtToEBITDARatio: 3 times
# DebtInstrumentCovenantMaximumDebtToEBITDARatio: 12 times
# DebtInstrumentCovenantNetDebtToEBITDARatio: 1 times
# RatioOfIndebtednessToEBITDA: 2 times
# DebtInstrumentCovenantConsolidatedIndebtednessToConsolidatedEBITDAMaximum: 1 times
# DebtToEbitdaRatioMaximum: 1 times

# %%
filtered_data = joinedFactsAndSubmissionsAnnual[joinedFactsAndSubmissionsAnnual['tag'].isin(debt_ebitda_tags)]
filtered_data
# Out:
#                          adsh  \
# 4698     0000004281-26-000012
# 4699     0000004281-26-000012
# 235101   0000058492-26-000107
# 235102   0000058492-26-000107
# 398156   0000093389-26-000012
# 717814   0000798354-26-000009
# 1138604  0001000623-26-000016
# 1453791  0001100682-26-000022
# 1485568  0001104659-26-012049
# 1485569  0001104659-26-012049
# 2190348  0001193125-26-063960
# 2199130  0001193125-26-064113
# 2316615  0001193125-26-071672
# 2316616  0001193125-26-071672
# 2852375  0001296445-26-000006
# 2852376  0001296445-26-000006
# 2852377  0001296445-26-000006
# 2852378  0001296445-26-000006
# 2852379  0001296445-26-000006
# 2852380  0001296445-26-000006
# 2852381  0001296445-26-000006
# 2852382  0001296445-26-000006
# 2852383  0001296445-26-000006
# 2951306  0001345126-26-000026
# 4008871  0001628280-26-009136
# 4008872  0001628280-26-009136
#
#                                                        tag     ddate  qtrs  \
# ...

# %%
filtered_data
# Out:
#                          adsh  \
# 4698     0000004281-26-000012
# 4699     0000004281-26-000012
# 235101   0000058492-26-000107
# 235102   0000058492-26-000107
# 398156   0000093389-26-000012
# 717814   0000798354-26-000009
# 1138604  0001000623-26-000016
# 1453791  0001100682-26-000022
# 1485568  0001104659-26-012049
# 1485569  0001104659-26-012049
# 2190348  0001193125-26-063960
# 2199130  0001193125-26-064113
# 2316615  0001193125-26-071672
# 2316616  0001193125-26-071672
# 2852375  0001296445-26-000006
# 2852376  0001296445-26-000006
# 2852377  0001296445-26-000006
# 2852378  0001296445-26-000006
# 2852379  0001296445-26-000006
# 2852380  0001296445-26-000006
# 2852381  0001296445-26-000006
# 2852382  0001296445-26-000006
# 2852383  0001296445-26-000006
# 2951306  0001345126-26-000026
# 4008871  0001628280-26-009136
# 4008872  0001628280-26-009136
#
#                                                        tag     ddate  qtrs  \
# ...

# %%
Interest_Coverage_Ratio = joinedFactsAndSubmissionsAnnual[
    joinedFactsAndSubmissionsAnnual['tag'].str.contains('Interest', case=False, na=False) &
    joinedFactsAndSubmissionsAnnual['tag'].str.contains('Coverage', case=False, na=False) & 
    joinedFactsAndSubmissionsAnnual['tag'].str.contains('Ratio', case=False, na=False)
]
Interest_Coverage_Ratio['tag'].unique()
# Out:
# array(['DebtInstrumentCovenantInterestCoverageRatioMinimum',
#        'DebtInstrumentCovenantInterestCoverageRatio',
#        'DebtInstrumentCovenantInterestCoverageRatioRequirementMinimum',
#        'DebtInstrumentCovenantComplianceUnencumberedInterestCoverageRatio',
#        'MinimumInterestCoverageRatio',
#        'DebtInstrumentInterestCoverageRatio',
#        'DebtInstrumentInterestCoverageRatioRequired',
#        'DebtInstrumentCovenantDescriptionMinimumInterestCoverageRatio',
#        'LineofCreditFacilityCovenantComplianceActualInterestCoverageRatio',
#        'DebtInstrumentCovenantInterestRateCoverageRatioMaximum',
#        'DebtInstrumentCovenantComplianceConsolidatedInterestCoverageRatio',
#        'InterestCoverageRatio',
#        'CovenantRequirementInterestCoverageRatio',
#        'DebtInstrumentCovenantTermsConsolidatedInterestCoverageRatio',
#        'DebtInstrumentCovenantTermsMinimumInterestCoverageRatio',
# ...

# %%
# Define the tags you want to check
Interest_Coverage_Ratio_tags = [
    'InterestCoverageRatio',
    'ConsolidatedInterestCoverageRatio',
    'DebtInstrumentCovenantActualInterestCoverageRatio',
    'DebtInstrumentCovenantComplianceConsolidatedInterestCoverageRatio',
    'DebtInstrumentCovenantInterestCoverageRatio',
    'DebtInstrumentCovenantMinimumInterestCoverageRatio',
    'DebtInstrumentConsolidatedInterestCoverageRatio',
    'DebtInstrumentCovenantComplianceMinimumInterestCoverageRatio',
    'LineofCreditFacilityCovenantComplianceActualInterestCoverageRatio',
    'DebtInstrumentCovenantConsolidatedInterestCoverageRatioMinimum'
]

# Count occurrences for each tag
for tag in Interest_Coverage_Ratio_tags:
    count = (joinedFactsAndSubmissionsAnnual['tag'] == tag).sum()
    if count > 0:
        print(f"{tag}: {count} times")
    else:
        print(f"{tag}: NOT FOUND")
# Out:
# InterestCoverageRatio: 23 times
# ConsolidatedInterestCoverageRatio: 5 times
# DebtInstrumentCovenantActualInterestCoverageRatio: 1 times
# DebtInstrumentCovenantComplianceConsolidatedInterestCoverageRatio: 5 times
# DebtInstrumentCovenantInterestCoverageRatio: 34 times
# DebtInstrumentCovenantMinimumInterestCoverageRatio: 10 times
# DebtInstrumentConsolidatedInterestCoverageRatio: 2 times
# DebtInstrumentCovenantComplianceMinimumInterestCoverageRatio: 1 times
# LineofCreditFacilityCovenantComplianceActualInterestCoverageRatio: 1 times
# DebtInstrumentCovenantConsolidatedInterestCoverageRatioMinimum: 3 times

# %%
filtered_data1 = joinedFactsAndSubmissionsAnnual[joinedFactsAndSubmissionsAnnual['tag'].isin(Interest_Coverage_Ratio_tags)]
filtered_data = pd.concat([filtered_data, filtered_data1], ignore_index=True)
filtered_data
# Out:
#                      adsh                                                tag  \
# 0    0000004281-26-000012  DebtInstrumentCovenantComplianceRatioOfConsoli...
# 1    0000004281-26-000012  DebtInstrumentCovenantComplianceRatioOfConsoli...
# 2    0000058492-26-000107                        RatioOfIndebtednessToEBITDA
# 3    0000058492-26-000107                        RatioOfIndebtednessToEBITDA
# 4    0000093389-26-000012     DebtInstrumentCovenantMaximumDebtToEBITDARatio
# ..                    ...                                                ...
# 106  0001673985-26-000008  DebtInstrumentCovenantConsolidatedInterestCove...
# 107  0001757073-26-000011                              InterestCoverageRatio
# 108  0001895262-26-000076        DebtInstrumentCovenantInterestCoverageRatio
# 109  0001941365-26-000006  DebtInstrumentCovenantMinimumInterestCoverageR...
# 110  0002089661-26-000016        DebtInstrumentCovenantInterestCoverageRatio
#
# ...

# %%
Current_Ratio = joinedFactsAndSubmissionsAnnual[
    joinedFactsAndSubmissionsAnnual['tag'].str.contains('Current', case=False, na=False) &
    joinedFactsAndSubmissionsAnnual['tag'].str.contains('Ratio', case=False, na=False)
]
Current_Ratio['tag'].unique()
# Out:
# array(['AssetAcquisitionConsiderationTransferredPercentOfActualPremiumsWrittenDuringCurrentYear',
#        'BusinessCombinationContingentConsiderationLiabilityNoncurrent',
#        'BusinessCombinationContingentConsiderationLiabilityCurrent',
#        'AssetsOfDisposalGroupIncludingDiscontinuedOperationCurrent',
#        'DisposalGroupIncludingDiscontinuedOperationDeferredRevenueCurrent',
#        'DisposalGroupIncludingDiscontinuedOperationOtherCurrentAssets',
#        'DisposalGroupIncludingDiscontinuedOperationOtherCurrentLiabilities',
#        'DisposalGroupIncludingDiscontinuedOperationOtherNoncurrentAssets',
#        'DisposalGroupIncludingDiscontinuedOperationPropertyPlantAndEquipmentCurrent',
#        'LiabilitiesOfDisposalGroupIncludingDiscontinuedOperationCurrent',
#        'BusinessCombinationContingentConsiderationLiabilityNoncurrentEarnoutPaymentsFairValue',
#        'BusinessCombinationContingentConsiderationLiabilityNoncurrentFinalPaymentFairValue',
# ...

# %%
# Define the tags you want to check
Current_Ratio_tags = [
    'CurrentRatio',
    'DebtServiceCoverageRatioCurrentFiscalYear',
    'DebtInstrumentCovenantComplianceCurrentRatio',
    'DebtInstrumentCovenantCurrentRatio',
    'MinimumCurrentRatioPerCreditFacility ',
    'MinimumCurrentRatioRequired',
    'DebtCovenantCurrentRatio',
    'LineOfCreditFacilityCovenantTermsMinimumCurrentRatio',
    'DebtInstrumentCovenantCurrentRatioMinimum',
    'FinancialCovenantsCurrentAssetsToCurrentLiabilitiesRatio',
    'DebtInstrumentCovenantComplianceCurrentRatio' 
]

# Count occurrences for each tag
for tag in Current_Ratio_tags:
    count = (joinedFactsAndSubmissionsAnnual['tag'] == tag).sum()
    if count > 0:
        print(f"{tag}: {count} times")
    else:
        print(f"{tag}: NOT FOUND")
# Out:
# CurrentRatio: 2 times
# DebtServiceCoverageRatioCurrentFiscalYear: 6 times
# DebtInstrumentCovenantComplianceCurrentRatio: 2 times
# DebtInstrumentCovenantCurrentRatio: 3 times
# MinimumCurrentRatioPerCreditFacility : NOT FOUND
# MinimumCurrentRatioRequired: 1 times
# DebtCovenantCurrentRatio: 1 times
# LineOfCreditFacilityCovenantTermsMinimumCurrentRatio: 1 times
# DebtInstrumentCovenantCurrentRatioMinimum: 1 times
# FinancialCovenantsCurrentAssetsToCurrentLiabilitiesRatio: 1 times
# DebtInstrumentCovenantComplianceCurrentRatio: 2 times

# %%
filtered_data1 = joinedFactsAndSubmissionsAnnual[joinedFactsAndSubmissionsAnnual['tag'].isin(Current_Ratio_tags)]
filtered_data = pd.concat([filtered_data, filtered_data1], ignore_index=True)
filtered_data
# Out:
#                      adsh                                                tag  \
# 0    0000004281-26-000012  DebtInstrumentCovenantComplianceRatioOfConsoli...
# 1    0000004281-26-000012  DebtInstrumentCovenantComplianceRatioOfConsoli...
# 2    0000058492-26-000107                        RatioOfIndebtednessToEBITDA
# 3    0000058492-26-000107                        RatioOfIndebtednessToEBITDA
# 4    0000093389-26-000012     DebtInstrumentCovenantMaximumDebtToEBITDARatio
# ..                    ...                                                ...
# 124  0001520006-26-000002  LineOfCreditFacilityCovenantTermsMinimumCurren...
# 125  0001621434-26-000018                                       CurrentRatio
# 126  0001658566-26-000035       DebtInstrumentCovenantComplianceCurrentRatio
# 127  0001698990-26-000005                 DebtInstrumentCovenantCurrentRatio
# 128  0001891027-26-000019          DebtInstrumentCovenantCurrentRatioMinimum
#
# ...

# %%
Operating_Cash_Flow_to_Total_Debt  = joinedFactsAndSubmissionsAnnual[
    joinedFactsAndSubmissionsAnnual['tag'].str.contains('Operating', case=False, na=False) &
    joinedFactsAndSubmissionsAnnual['tag'].str.contains('Cash', case=False, na=False)&
    joinedFactsAndSubmissionsAnnual['tag'].str.contains('Flow', case=False, na=False)&
    joinedFactsAndSubmissionsAnnual['tag'].str.contains('Debt', case=False, na=False)



]
Operating_Cash_Flow_to_Total_Debt['tag'].unique()
# Out:
# array(['NetDebtToOperatingCashFlowMaximumRatio',
#        'RatioOfNetDebtToOperatingCashFlow'], dtype=object)

# %%
# Define the tags you want to check
Operating_Cash_Flow_to_Total_Debt_tags = [
    'NetDebtToOperatingCashFlowMaximumRatio',
       'RatioOfNetDebtToOperatingCashFlow']

# Count occurrences for each tag
for tag in Operating_Cash_Flow_to_Total_Debt_tags:
    count = (joinedFactsAndSubmissionsAnnual['tag'] == tag).sum()
    if count > 0:
        print(f"{tag}: {count} times")
    else:
        print(f"{tag}: NOT FOUND")
# Out:
# NetDebtToOperatingCashFlowMaximumRatio: 1 times
# RatioOfNetDebtToOperatingCashFlow: 1 times

# %%
filtered_data1 = joinedFactsAndSubmissionsAnnual[joinedFactsAndSubmissionsAnnual['tag'].isin(Operating_Cash_Flow_to_Total_Debt_tags)]
filtered_data = pd.concat([filtered_data, filtered_data1], ignore_index=True)
filtered_data
# Out:
#                      adsh                                                tag  \
# 0    0000004281-26-000012  DebtInstrumentCovenantComplianceRatioOfConsoli...
# 1    0000004281-26-000012  DebtInstrumentCovenantComplianceRatioOfConsoli...
# 2    0000058492-26-000107                        RatioOfIndebtednessToEBITDA
# 3    0000058492-26-000107                        RatioOfIndebtednessToEBITDA
# 4    0000093389-26-000012     DebtInstrumentCovenantMaximumDebtToEBITDARatio
# ..                    ...                                                ...
# 126  0001658566-26-000035       DebtInstrumentCovenantComplianceCurrentRatio
# 127  0001698990-26-000005                 DebtInstrumentCovenantCurrentRatio
# 128  0001891027-26-000019          DebtInstrumentCovenantCurrentRatioMinimum
# 129  0001104659-26-013854             NetDebtToOperatingCashFlowMaximumRatio
# 130  0001104659-26-013854                  RatioOfNetDebtToOperatingCashFlow
#
# ...

# %%
Debt_To_Equity = joinedFactsAndSubmissionsAnnual[
    joinedFactsAndSubmissionsAnnual['tag'].str.contains('Debt', case=False, na=False) &
    joinedFactsAndSubmissionsAnnual['tag'].str.contains('Equity', case=False, na=False)
]
Debt_To_Equity['tag'].unique()
# Out:
# array(['DebtAndEquitySecuritiesAvailableForSale',
#        'DebtAndEquitySecuritiesAvailableForSaleAmortizedCost',
#        'DebtAndEquitySecuritiesUnrealizedGain',
#        'DebtAndEquitySecuritiesUnrealizedLoss',
#        'DebtInstrumentCovenantCommonEquityTierOneRatio',
#        'DebtInstrumentRepurchaseReductionToEquity',
#        'DebtAndEquitySecuritiesUnrealizedGainLoss',
#        'DebtAndEquitySecuritiesGainLoss',
#        'LimitedPartnershipsInvestedInPrivateDebtAndEquity',
#        'PercentageOfLimitedPartnershipsInvestedInPrivateDebtAndEquity',
#        'Proceedsfromsalesandmaturitiesofavailableforsaledebtequityandothersecurities',
#        'EquityMethodInvestmentSummarizedFinancialInformationDebt',
#        'CapitalizationLongtermDebtAndEquity',
#        'DebtSecuritiesTradingAndEquitySecuritiesFvNiCost',
#        'DebtAndEquitySecuritiesRealizedGainLoss',
#        'DebtAndEquitySecuritiesRealizedGain',
#        'DebtAndEquitySecuritiesRealizedLoss',
# ...

# %%
# Define the tags you want to check
Debt_To_Equity_tags = [
    'DebtToEquityRatio',
       'DebtEquityRatio',
    'NetDebtToEquityRatio',
    'DebtInstrumentCovenantDebtToEquityRatio',
    'DebtInstrumentCovenantDebtToEquityRatioMaximum',
    'RatioOfDebtToDebtPlusEquity',
    'DebtCovenantRatioOfDebtToDebtPlusEquity',
    'TargetedMaximumDebtToEquityRatio',
    'LineofCreditFacilityCovenantTermsMaximumDebttoEquityRatio',
    'DebtInstrumentCovenantDebtToAllowanceAndEquityRatioMaximum']

# Count occurrences for each tag
for tag in Debt_To_Equity_tags:
    count = (joinedFactsAndSubmissionsAnnual['tag'] == tag).sum()
    if count > 0:
        print(f"{tag}: {count} times")
    else:
        print(f"{tag}: NOT FOUND")
# Out:
# DebtToEquityRatio: 3 times
# DebtEquityRatio: 1 times
# NetDebtToEquityRatio: 2 times
# DebtInstrumentCovenantDebtToEquityRatio: 1 times
# DebtInstrumentCovenantDebtToEquityRatioMaximum: 2 times
# RatioOfDebtToDebtPlusEquity: 1 times
# DebtCovenantRatioOfDebtToDebtPlusEquity: 1 times
# TargetedMaximumDebtToEquityRatio: 1 times
# LineofCreditFacilityCovenantTermsMaximumDebttoEquityRatio: 3 times
# DebtInstrumentCovenantDebtToAllowanceAndEquityRatioMaximum: 1 times

# %%
filtered_data1 = joinedFactsAndSubmissionsAnnual[joinedFactsAndSubmissionsAnnual['tag'].isin(Debt_To_Equity_tags)]
filtered_data = pd.concat([filtered_data, filtered_data1], ignore_index=True)
filtered_data
# Out:
#                      adsh                                                tag  \
# 0    0000004281-26-000012  DebtInstrumentCovenantComplianceRatioOfConsoli...
# 1    0000004281-26-000012  DebtInstrumentCovenantComplianceRatioOfConsoli...
# 2    0000058492-26-000107                        RatioOfIndebtednessToEBITDA
# 3    0000058492-26-000107                        RatioOfIndebtednessToEBITDA
# 4    0000093389-26-000012     DebtInstrumentCovenantMaximumDebtToEBITDARatio
# ..                    ...                                                ...
# 142  0001496099-26-000008     DebtInstrumentCovenantDebtToEquityRatioMaximum
# 143  0001628280-26-012830                                  DebtToEquityRatio
# 144  0001630472-26-000004            DebtInstrumentCovenantDebtToEquityRatio
# 145  0002070979-26-000018                               NetDebtToEquityRatio
# 146  0002070979-26-000018                               NetDebtToEquityRatio
#
# ...

# %%
Credit_Risk = joinedFactsAndSubmissionsAnnual[
    joinedFactsAndSubmissionsAnnual['tag'].str.contains('Credit', case=False, na=False) &
    joinedFactsAndSubmissionsAnnual['tag'].str.contains('Risk', case=False, na=False)
]
Credit_Risk['tag'].unique()
# Out:
# array(['ConcentrationRiskCreditRiskFinancialInstrumentMaximumExposure',
#        'DerivativeCreditRiskValuationAdjustmentDerivativeAssets',
#        'DerivativeCreditRiskValuationAdjustmentDerivativeLiabilities',
#        'AdjustmentsToFairValueOfDerivativeContractsDueToCreditRisk',
#        'LoansAndLeasesReceivableNumberOfMethodsToAssessCreditRisk',
#        'FairValueInputsCreditRisk',
#        'FairValueOptionCreditRiskGainsLossesOnAssets',
#        'MaximumCreditRiskForRecourseAssociatedWithLoansSoldUnderFederalNationalMortgageAssociationDelegatedUnderwritingAndServicingProgram',
#        'CreditRiskDerivativesPurchasedatFairValue',
#        'CreditRiskDerivativesSoldatFairValue',
#        'MaximumExposureUnderCreditRiskAgreementAssumingCustomerDefault',
#        'CreditRiskDerivativesAtFairValueNet',
#        'AggregateCreditRiskNetOfCollateral',
#        'CreditRisksFromInterestRateSwapsUsedForTradingPurposes',
# ...

# %%
# Define the tags you want to check
Credit_risk_tags = [
    'MaximumExposureToCreditRisk',
       'NetExposureToCreditRisk',
    'ConcentrationRiskCreditRiskFinancialInstrumentMaximumExposure',
    'MaximumExposureToCreditRiskOfFinancialAssets',
    'CreditRiskExposureToBankingAndFinancialSectorPercentage']

# Count occurrences for each tag
for tag in Credit_risk_tags:
    count = (joinedFactsAndSubmissionsAnnual['tag'] == tag).sum()
    if count > 0:
        print(f"{tag}: {count} times")
    else:
        print(f"{tag}: NOT FOUND")
# Out:
# MaximumExposureToCreditRisk: 2237 times
# NetExposureToCreditRisk: 128 times
# ConcentrationRiskCreditRiskFinancialInstrumentMaximumExposure: 297 times
# MaximumExposureToCreditRiskOfFinancialAssets: 15 times
# CreditRiskExposureToBankingAndFinancialSectorPercentage: 1 times

# %%
filtered_data1 = joinedFactsAndSubmissionsAnnual[joinedFactsAndSubmissionsAnnual['tag'].isin(Credit_risk_tags)]
filtered_data = pd.concat([filtered_data, filtered_data1], ignore_index=True)
filtered_data
# Out:
#                       adsh                                                tag  \
# 0     0000004281-26-000012  DebtInstrumentCovenantComplianceRatioOfConsoli...
# 1     0000004281-26-000012  DebtInstrumentCovenantComplianceRatioOfConsoli...
# 2     0000058492-26-000107                        RatioOfIndebtednessToEBITDA
# 3     0000058492-26-000107                        RatioOfIndebtednessToEBITDA
# 4     0000093389-26-000012     DebtInstrumentCovenantMaximumDebtToEBITDARatio
# ...                    ...                                                ...
# 2820  0001988894-26-000004                        MaximumExposureToCreditRisk
# 2821  0001988894-26-000004                        MaximumExposureToCreditRisk
# 2822  0001988894-26-000004                        MaximumExposureToCreditRisk
# 2823  0001988894-26-000004                        MaximumExposureToCreditRisk
# 2824  0001988894-26-000004                        MaximumExposureToCreditRisk
#
# ...

# %%
filtered_data1.to_csv('filtered_data.csv', index=False)

# %%
Risk_factor = joinedTextAndSubmissionsAnnual[
    joinedTextAndSubmissionsAnnual['tag'].str.contains('Factor', case=False, na=False) &
    joinedTextAndSubmissionsAnnual['tag'].str.contains('Risk', case=False, na=False)
]
Risk_factor['tag'].unique()
# Out:
# array(['SchedulesOfConcentrationOfRiskByRiskFactorTextBlock',
#        'SchedulesOfConcentrationOfRiskByRiskFactorRelatedToCollaborativePartnersTableTextBlock',
#        'DisclosureOfNatureAndExtentOfRisksByRiskFactorTextBlock',
#        'DescriptionOfFinancialRiskFactorsAndRiskManagementPolicyTextBlock',
#        'RiskFactorsTableTextBlock', 'VaRByRiskFactorTableTextBlock'],
#       dtype=object)

# %%
# Define the tags you want to check
Risk_factor_tags = ['SchedulesOfConcentrationOfRiskByRiskFactorTextBlock',
       'SchedulesOfConcentrationOfRiskByRiskFactorRelatedToCollaborativePartnersTableTextBlock',
       'DisclosureOfNatureAndExtentOfRisksByRiskFactorTextBlock',
       'DescriptionOfFinancialRiskFactorsAndRiskManagementPolicyTextBlock',
       'RiskFactorsTableTextBlock', 'VaRByRiskFactorTableTextBlock']

# Count occurrences for each tag
for tag in Risk_factor_tags:
    count = (joinedTextAndSubmissionsAnnual['tag'] == tag).sum()
    if count > 0:
        print(f"{tag}: {count} times")
    else:
        print(f"{tag}: NOT FOUND")
# Out:
# SchedulesOfConcentrationOfRiskByRiskFactorTextBlock: 222 times
# SchedulesOfConcentrationOfRiskByRiskFactorRelatedToCollaborativePartnersTableTextBlock: 1 times
# DisclosureOfNatureAndExtentOfRisksByRiskFactorTextBlock: 1 times
# DescriptionOfFinancialRiskFactorsAndRiskManagementPolicyTextBlock: 1 times
# RiskFactorsTableTextBlock: 131 times
# VaRByRiskFactorTableTextBlock: 1 times

# %%
filtered_data1 = joinedTextAndSubmissionsAnnual[joinedTextAndSubmissionsAnnual['tag'].isin(Risk_factor_tags)]
filtered_data1
# Out:
#                         adsh  \
# 1825    0000004904-26-000013
# 31853   0000073124-26-000016
# 33019   0000076605-26-000013
# 34064   0000078003-26-000026
# 36316   0000085535-26-000008
# ...                      ...
# 672238  0001880319-26-000013
# 673835  0001895262-26-000076
# 675234  0001907982-26-000026
# 677107  0001934850-26-000026
# 680415  0001981599-26-000020
#
#                                                       tag       version  \
# 1825    SchedulesOfConcentrationOfRiskByRiskFactorText...  us-gaap/2025
# 31853   SchedulesOfConcentrationOfRiskByRiskFactorText...  us-gaap/2025
# 33019   SchedulesOfConcentrationOfRiskByRiskFactorText...  us-gaap/2025
# 34064   SchedulesOfConcentrationOfRiskByRiskFactorText...  us-gaap/2025
# 36316   SchedulesOfConcentrationOfRiskByRiskFactorText...  us-gaap/2025
# ...                                                   ...           ...
# 672238  SchedulesOfConcentrationOfRiskByRiskFactorText...  us-gaap/2025
# ...

# %%
Credit_Risk = joinedTextAndSubmissionsAnnual[
    joinedTextAndSubmissionsAnnual['tag'].str.contains('Credit', case=False, na=False) &
    joinedTextAndSubmissionsAnnual['tag'].str.contains('Risk', case=False, na=False)
]
Credit_Risk['tag'].unique()
# Out:
# array(['ConcentrationRiskCreditRisk',
#        'ConcentrationRiskCreditRiskFinancialInstrumentsTableTextBlock',
#        'ScheduleOfCededCreditRiskByReinsurerTextBlock',
#        'ConcentrationRiskCreditRiskPolicyAndOffBalanceSheetCreditExposurePolicyPolicyTextBlock',
#        'CreditRiskAssociatedWithCommitmentsTableTextBlock',
#        'CreditRiskAssociatedWithLettersOfCreditTableTextBlock',
#        'NotionalAndCreditRiskAmountsOfOutstandingDerivativePositionsTableTextBlock',
#        'ConcentrationOfCreditRisksExposuresAndFinancialInstrumentsPolicyPolicyTextBlock',
#        'ScheduleofDerivativeContractsCreditRiskContingentFeaturesTableTextBlock',
#        'AverageTermOfCreditRiskDerivatives1',
#        'CreditRiskRelatedContingentFeaturesTableTextBlock',
#        'SummaryOfCreditRatingsOfCreditRiskRelatedGuaranteesTableTableTextBlock',
#        'DerivativesCreditRiskRiskParticipationAgreementsTableTextBlock',
# ...

# %%
# Define the tags you want to check
Risk_factor_tags = ['ConcentrationRiskCreditRisk']

# Count occurrences for each tag
for tag in Risk_factor_tags:
    count = (joinedTextAndSubmissionsAnnual['tag'] == tag).sum()
    if count > 0:
        print(f"{tag}: {count} times")
    else:
        print(f"{tag}: NOT FOUND")
# Out:
# ConcentrationRiskCreditRisk: 716 times

# %%
# Get the first matching row
first_match = joinedTextAndSubmissionsAnnual[joinedTextAndSubmissionsAnnual['tag'] == 'ConcentrationRiskCreditRisk'].iloc[0]

# Then access a column, for example 'value'
value = first_match['value']
print(value)
# Out:
# Concentration of Credit Risk Financial instruments that potentially subject us to a concentration of counterparty credit risk, or the risk that a counterparty will be unable to meet its commitments, consist principally of accounts receivable and contract assets related to our long-term SPAs, as our contracted LNG sales are primarily under SPAs with terms exceeding 10 years. As of December 31, 2025, we had SPAs with initial terms of 10 or more years with approximately 30 different third party customers, with customers under common control being considered a single customer. We are dependent on the respective customers creditworthiness and their ability to perform under their respective agreements. While substantially all of our long-term third party customer arrangements are executed with a creditworthy company or secured by a parent company guarantee or other form of collateral, we are nonetheless exposed to credit risk in the event of a customer default that requires us to seek reco
# ...

# %%
credit_tags = set(Credit_Risk['tag'].unique())
final_tags = set(filtered_data['tag'].unique())
common_tags = credit_tags.intersection(final_tags)

print(f"Number of matching tags: {len(common_tags)}")
print(common_tags)
# Out:
# Number of matching tags: 0
# set()

# %%
# Define the tags you want to check
Risk_credit_tags = ['ConcentrationRiskCreditRisk',
                    'ConcentrationRiskCreditRiskFinancialInstruments', 
                    'ConcentrationOfCreditRiskPolicyTextBlock',
                   'CreditRiskPolicyPolicyTextBlock',
                    'CreditRiskPolicyTextBlock'
                    , 'CreditRiskAndAllowanceForDoubtfulAccountsPolicyTextBlock',
"DisclosureOfCreditRiskExplanatory", "DisclosureOfCreditRiskExposureExplanatory", "ConcentrationOfCreditRiskPolicyTextBlock", "DisclosureOfCreditQualityOfAssetsExposedToCreditRiskTextBlock", "CreditRiskRelatedContingentFeaturesTableTextBlock", "MaximumCreditRiskExposureTableTextBlock", "DisclosureOfEffectOfCreditRiskMitigationTableTextBlock", "AccountsReceivableAndCreditRiskPolicyTextBlock", "OffBalanceSheetRiskAndConcentrationOfCreditRiskPolicyTextBlock"]

# Count occurrences for each tag
for tag in Risk_credit_tags:
    count = (joinedTextAndSubmissionsAnnual['tag'] == tag).sum()
    if count > 0:
        print(f"{tag}: {count} times")
    else:
        print(f"{tag}: NOT FOUND")
# Out:
# ConcentrationRiskCreditRisk: 716 times
# ConcentrationRiskCreditRiskFinancialInstruments: 1 times
# ConcentrationOfCreditRiskPolicyTextBlock: 9 times
# CreditRiskPolicyPolicyTextBlock: 1 times
# CreditRiskPolicyTextBlock: 1 times
# CreditRiskAndAllowanceForDoubtfulAccountsPolicyTextBlock: 1 times
# DisclosureOfCreditRiskExplanatory: 15 times
# DisclosureOfCreditRiskExposureExplanatory: 20 times
# ConcentrationOfCreditRiskPolicyTextBlock: 9 times
# DisclosureOfCreditQualityOfAssetsExposedToCreditRiskTextBlock: 2 times
# CreditRiskRelatedContingentFeaturesTableTextBlock: 1 times
# MaximumCreditRiskExposureTableTextBlock: 1 times
# DisclosureOfEffectOfCreditRiskMitigationTableTextBlock: 1 times
# AccountsReceivableAndCreditRiskPolicyTextBlock: 1 times
# OffBalanceSheetRiskAndConcentrationOfCreditRiskPolicyTextBlock: 1 times

# %%
filtered_data2 = joinedTextAndSubmissionsAnnual[joinedTextAndSubmissionsAnnual['tag'].isin(Risk_credit_tags)]
filtered_data1= pd.concat([filtered_data1, filtered_data2], ignore_index=True)
filtered_data1
# Out:
#                       adsh                                                tag  \
# 0     0000004904-26-000013  SchedulesOfConcentrationOfRiskByRiskFactorText...
# 1     0000073124-26-000016  SchedulesOfConcentrationOfRiskByRiskFactorText...
# 2     0000076605-26-000013  SchedulesOfConcentrationOfRiskByRiskFactorText...
# 3     0000078003-26-000026  SchedulesOfConcentrationOfRiskByRiskFactorText...
# 4     0000085535-26-000008  SchedulesOfConcentrationOfRiskByRiskFactorText...
# ...                    ...                                                ...
# 1123  0002013745-26-000007                        ConcentrationRiskCreditRisk
# 1124  0002038564-26-000004                        ConcentrationRiskCreditRisk
# 1125  0002046386-26-000009                        ConcentrationRiskCreditRisk
# 1126  0002067129-26-000007                        ConcentrationRiskCreditRisk
# 1127  0002074176-26-000010                        ConcentrationRiskCreditRisk
#
# ...

# %%
Liquidity_Risk = joinedTextAndSubmissionsAnnual[
    joinedTextAndSubmissionsAnnual['tag'].str.contains('Liquidity', case=False, na=False) &
    joinedTextAndSubmissionsAnnual['tag'].str.contains('Risk', case=False, na=False)
]
Liquidity_Risk['tag'].unique()
# Out:
# array(['DisclosureOfMaturityAnalysisForFinancialAssetsHeldForManagingLiquidityRiskExplanatory',
#        'DisclosureOfLiquidityRiskExplanatory',
#        'ScheduleOfKeyFiguresForLiquidityRiskTableTextBlock',
#        'DescriptionOfManagingLiquidityRisk',
#        'DisclosureOfMaturityAnalysisForLiquidityRiskThatArisesFromContractsWithinScopeOfIFRS17Explanatory',
#        'RisksAndLiquidityTextBlock', 'LiquidityRiskPolicyTextBlock',
#        'DisclosureOfCurrentCreditAndLiquidityRiskOfDerivativesTableTextBlock',
#        'RisksAndUncertaintiesAndLiquidityPolicyTextBlock',
#        'RiskAndLiquidityDisclosureTextBlock'], dtype=object)

# %%
# Define the tags you want to check
Liquidity_Risk_tags = ['DisclosureOfMaturityAnalysisForFinancialAssetsHeldForManagingLiquidityRiskExplanatory',
       'DisclosureOfLiquidityRiskExplanatory',
       'ScheduleOfKeyFiguresForLiquidityRiskTableTextBlock',
       'DescriptionOfManagingLiquidityRisk',
       'DisclosureOfMaturityAnalysisForLiquidityRiskThatArisesFromContractsWithinScopeOfIFRS17Explanatory',
       'RisksAndLiquidityTextBlock', 'LiquidityRiskPolicyTextBlock',
       'DisclosureOfCurrentCreditAndLiquidityRiskOfDerivativesTableTextBlock',
       'RisksAndUncertaintiesAndLiquidityPolicyTextBlock',
       'RiskAndLiquidityDisclosureTextBlock']

# Count occurrences for each tag
for tag in Liquidity_Risk_tags:
    count = (joinedTextAndSubmissionsAnnual['tag'] == tag).sum()
    if count > 0:
        print(f"{tag}: {count} times")
    else:
        print(f"{tag}: NOT FOUND")
# Out:
# DisclosureOfMaturityAnalysisForFinancialAssetsHeldForManagingLiquidityRiskExplanatory: 3 times
# DisclosureOfLiquidityRiskExplanatory: 8 times
# ScheduleOfKeyFiguresForLiquidityRiskTableTextBlock: 1 times
# DescriptionOfManagingLiquidityRisk: 4 times
# DisclosureOfMaturityAnalysisForLiquidityRiskThatArisesFromContractsWithinScopeOfIFRS17Explanatory: 4 times
# RisksAndLiquidityTextBlock: 1 times
# LiquidityRiskPolicyTextBlock: 1 times
# DisclosureOfCurrentCreditAndLiquidityRiskOfDerivativesTableTextBlock: 1 times
# RisksAndUncertaintiesAndLiquidityPolicyTextBlock: 1 times
# RiskAndLiquidityDisclosureTextBlock: 1 times

# %%
filtered_data2 = joinedTextAndSubmissionsAnnual[joinedTextAndSubmissionsAnnual['tag'].isin(Liquidity_Risk_tags)]
filtered_data1= pd.concat([filtered_data1, filtered_data2], ignore_index=True)
filtered_data1
# Out:
#                       adsh                                                tag  \
# 0     0000004904-26-000013  SchedulesOfConcentrationOfRiskByRiskFactorText...
# 1     0000073124-26-000016  SchedulesOfConcentrationOfRiskByRiskFactorText...
# 2     0000076605-26-000013  SchedulesOfConcentrationOfRiskByRiskFactorText...
# 3     0000078003-26-000026  SchedulesOfConcentrationOfRiskByRiskFactorText...
# 4     0000085535-26-000008  SchedulesOfConcentrationOfRiskByRiskFactorText...
# ...                    ...                                                ...
# 1148  0001628280-26-006874               DisclosureOfLiquidityRiskExplanatory
# 1149  0001628280-26-008131  DisclosureOfCurrentCreditAndLiquidityRiskOfDer...
# 1150  0001628280-26-009886   RisksAndUncertaintiesAndLiquidityPolicyTextBlock
# 1151  0001628280-26-010858               DisclosureOfLiquidityRiskExplanatory
# 1152  0001821586-26-000002                RiskAndLiquidityDisclosureTextBlock
#
# ...

# %%
filtered_data1.to_csv('text_filtered_data.csv', index=False)
